# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  str
# dtypes: float64(9), str(1)
# memory usage: 1.6 MB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  str
# dtypes: float64(9), str(1)
# memory usage: 1.7 MB

# %%
from sklearn.model_selection import train_test_split

X = data.drop(['median_house_value'], axis=1)
y = data['median_house_value']

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
x_train,X_test,Y_train,Y_test = train_test_split(X,y,test_size = 0.2)

# %%
training_data = x_train.join(Y_train)
testing_data = X_test.join(Y_test)

# %%
training_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5888     -118.33     34.15                44.0       1321.0           303.0
# 6996     -118.03     33.95                34.0       1882.0           428.0
# 8850     -118.41     34.09                37.0       2716.0           302.0
# 12850    -121.37     38.69                35.0       1093.0           192.0
# 13226    -117.68     34.01                20.0       7326.0          1555.0
# ...          ...       ...                 ...          ...             ...
# 5735     -118.23     34.15                26.0       1649.0           522.0
# 16436    -121.30     38.09                31.0        335.0            53.0
# 17595    -121.89     37.31                40.0       1844.0           340.0
# 9371     -122.53     37.92                42.0       1741.0           301.0
# 15032    -116.99     32.79                33.0       2420.0           393.0
#
#        population  households  median_income ocean_proximity  \
# 5888        471.0       301.0         4.2679       <1H OCEAN
# 6996       1034.0       375.0         3.6509       <1H OCEAN
# 8850        809.0       291.0        15.0001       <1H OCEAN
# 12850       590.0       190.0         2.7009          INLAND
# 13226      5718.0      1538.0         3.2073          INLAND
# ...           ...         ...            ...             ...
# 5735       1332.0       483.0         3.1004       <1H OCEAN
# 16436       154.0        55.0         2.0694          INLAND
# 17595       719.0       305.0         3.3682       <1H OCEAN
# 9371        723.0       306.0         5.5379        NEAR BAY
# 15032      1003.0       397.0         4.0658       <1H OCEAN
#
#        median_house_value
# 5888             331800.0
# 6996             173200.0
# 8850             500001.0
# 12850             80200.0
# 13226            123500.0
# ...                   ...
# 5735             257100.0
# 16436            175000.0
# 17595            235200.0
# 9371             410500.0
# 15032            165100.0
#
# [16346 rows x 10 columns]

# %%
training_data.hist(figsize = (15,10))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(training_data.corr(numeric_only=True), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
training_data['total_rooms'] = np.log(training_data['total_rooms'] + 1)
training_data['total_bedrooms'] = np.log(training_data['total_bedrooms'] + 1)
training_data['population'] = np.log(training_data['population'] + 1)
training_data['households'] = np.log(training_data['households'] + 1)

training_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
training_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7170
# INLAND        5271
# NEAR OCEAN    2095
# NEAR BAY      1806
# ISLAND           4
# Name: count, dtype: int64

# %%
training_data=training_data.join(pd.get_dummies(training_data.ocean_proximity)).drop(['ocean_proximity'], axis=1)

# %%
training_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5888     -118.33     34.15                44.0     7.186901        5.717028
# 6996     -118.03     33.95                34.0     7.540622        6.061457
# 8850     -118.41     34.09                37.0     7.907284        5.713733
# 12850    -121.37     38.69                35.0     6.997596        5.262690
# 13226    -117.68     34.01                20.0     8.899321        7.349874
# ...          ...       ...                 ...          ...             ...
# 5735     -118.23     34.15                26.0     7.408531        6.259581
# 16436    -121.30     38.09                31.0     5.817111        3.988984
# 17595    -121.89     37.31                40.0     7.520235        5.831882
# 9371     -122.53     37.92                42.0     7.462789        5.710427
# 15032    -116.99     32.79                33.0     7.791936        5.976351
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 5888     6.156979    5.710427         4.2679            331800.0       True
# 6996     6.942157    5.929589         3.6509            173200.0       True
# 8850     6.697034    5.676754        15.0001            500001.0       True
# 12850    6.381816    5.252273         2.7009             80200.0      False
# 13226    8.651549    7.338888         3.2073            123500.0      False
# ...           ...         ...            ...                 ...        ...
# 5735     7.195187    6.182085         3.1004            257100.0       True
# 16436    5.043425    4.025352         2.0694            175000.0      False
# 17595    6.579251    5.723585         3.3682            235200.0       True
# 9371     6.584791    5.726848         5.5379            410500.0      False
# 15032    6.911747    5.986452         4.0658            165100.0       True
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 5888    False   False     False       False
# 6996    False   False     False       False
# 8850    False   False     False       False
# 12850    True   False     False       False
# 13226    True   False     False       False
# ...       ...     ...       ...         ...
# 5735    False   False     False       False
# 16436    True   False     False       False
# 17595   False   False     False       False
# 9371    False   False      True       False
# 15032   False   False     False       False
#
# [16346 rows x 14 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(training_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15, 8))
sns.scatterplot(x="latitude", y="longitude", data=training_data, hue="median_house_value", palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
training_data['bedroom_ratio'] = training_data['total_bedrooms'] / training_data['total_rooms']
training_data['household_rooms'] = training_data['total_rooms'] / training_data['households']

plt.figure(figsize=(15,8))
sns.heatmap(training_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression

X_train, y_train = training_data.drop(['median_house_value'], axis=1), training_data['median_house_value']

reg = LinearRegression()

reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
test_data = X_test.join(Y_test)

test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
test_data['population'] = np.log(test_data['population'] + 1)
test_data['households'] = np.log(test_data['households'] + 1)

test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'], axis=1)


test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
test_data['household_rooms'] = test_data['total_rooms'] / test_data['households']

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12632    -121.48     38.49                26.0     8.060224        6.693324
# 10397    -117.67     33.56                 4.0     8.098643        6.591674
# 5486     -118.46     33.98                27.0     7.704361        6.255750
# 3515     -118.47     34.25                34.0     7.457609        5.991465
# 1451     -121.97     37.97                27.0     7.433667        5.669881
# ...          ...       ...                 ...          ...             ...
# 6813     -118.07     34.10                28.0     6.517671        5.181784
# 6717     -118.15     34.13                50.0     7.801391        6.204558
# 1991     -119.80     36.72                43.0     7.160069        5.888878
# 13449    -117.40     34.08                21.0     8.195058        6.504288
# 14014    -117.18     32.75                36.0     7.733246        6.282267
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 12632    7.803027    6.624065         1.5908             78600.0      False
# 10397    7.204893    6.450470         4.6863            184400.0       True
# 5486     6.693324    6.129050         3.8935            500001.0       True
# 3515     7.021976    5.996452         4.1492            195700.0       True
# 1451     6.694562    5.693732         6.1168            210500.0      False
# ...           ...         ...            ...                 ...        ...
# 6813     6.298949    5.225747         3.2361            187500.0       True
# 6717     6.854355    6.113682         4.7344            314700.0       True
# 1991     6.880384    5.846439         0.9513             50400.0      False
# 13449    7.825645    6.580639         3.8531            105400.0      False
# 14014    6.823286    6.276643         2.7222            284700.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 12632    True   False     False       False       0.830414         1.216809
# 10397   False   False     False       False       0.813923         1.255512
# 5486    False   False     False       False       0.811975         1.257024
# 3515    False   False     False       False       0.803403         1.243670
# 1451     True   False     False       False       0.762730         1.305588
# ...       ...     ...       ...         ...            ...              ...
# 6813    False   False     False       False       0.795036         1.247223
# 6717    False   False     False       False       0.795314         1.276054
# 1991     True   False     False       False       0.822461         1.224689
# 13449    True   False     False       False       0.793684         1.245329
# 14014   False   False     False        True       0.812371         1.232067
#
# [4087 rows x 16 columns]

# %%
X_test, Y_test = test_data.drop(['median_house_value'], axis=1), test_data['median_house_value']
X_test = X_test.reindex(columns=X_train.columns, fill_value=0)
reg.score(X_test, Y_test)
# Out:
# 0.6702168459472557

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train, y_train = training_data.drop(['median_house_value'], axis=1), training_data['median_house_value']
X_train_s = scaler.fit_transform(X_train)

reg = LinearRegression()

reg.fit(X_train_s, y_train)
# Out:
# LinearRegression()

# %%
X_test_s = scaler.transform(X_test)

# %%
reg.score(X_test_s, Y_test)
# Out:
# 0.6702168459472557

# %%
from sklearn.ensemble import RandomForestRegressor
forest = RandomForestRegressor()
forest.fit(X_train, Y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test, Y_test)
# Out:
# 0.819508786369437

# %%
from sklearn.model_selection import GridSearchCV

forest = RandomForestRegressor()

param_grid = {
    "n_estimators": [3, 10, 30],
    "max_features": [2, 4, 6, 8]
}

grid_search = GridSearchCV(forest, param_grid, cv=5,
                           scoring="neg_mean_squared_error",
                           return_train_score=True)

grid_search.fit(X_train_s, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': [2, 4, 6, 8],
#                          'n_estimators': [3, 10, 30]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_test = grid_search.best_estimator_

# %%
best_test.score(X_test_s, Y_test)
# Out:
# 0.8106675884846041
